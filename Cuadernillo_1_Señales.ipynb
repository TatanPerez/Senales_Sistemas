# %% [markdown]
# <a href="https://colab.research.google.com/github/TatanPerez/Python_Basico/blob/main/Cuadernillo_1_Se%C3%B1ales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wilmer Sebastian Perez Cuastumal
#
# Cuadernillo 1 (Simulando señal)
#
# 22/02/2024

# %% [markdown]
# x(t)= 8Cos(100t) + 10Sen(20t) -7Cos(300t - pi/7)

# %%
# crear vector tiempo por rango y por número de muestras
K = 200 # número de muestras
ti = -15 # tiempo incial referencia [s]
tf = 10 # tieimpo final  [s]
# vector de tiempo equiespacioado
tv = np.linspace(start=ti,stop=tf,num=K)
print(tv)
print(tv.shape)
# tiempo muestreo se define según el rango de trabajo en segundos y la cantidad de muestras
Ts = (tf - ti)/K
print(Ts)

# %%
import matplotlib.pyplot as plt
import numpy as np
w1 = 100
w2 = 20
w3 = 300
Ts = np.pi/10
A = 8
B = 10
C = -7
ti = 0
t1 = np.pi/50
t2 = np.pi/10
t3 = np.pi/150
tf = 2*Ts
tv = np.arange(ti,tf,t3/10)

xv = A * np.cos(w1*tv)+ B*np.sin(w2*tv)+ C*np.cos(w2*tv-(np.pi/7))
plt.plot(tv, xv)
plt.xlabel('Tiempo [s]')
plt.ylabel('$x(t)= 8Cos(100t) + 10Sen(20t) -7Cos(300t - pi/7)$')
plt.title('Grafico de $xv$')
plt.show()

# %%
#cero y pendiente
ycs = my_ceropen(y, ymin=0,ymax=20)

#número de bits y vector de cuantización
nbits = 3
rmin = 0
rmax = 10
ve = np.linspace(rmin,rmax,2**nbits) # (rmax-rmin)/(2^#bits - 1) -> si se quiere incluir rmin y rmax
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a7b9cc830a58> in <cell line: 2>()
#       1 #cero y pendiente
# ----> 2 ycs = my_ceropen(y, ymin=0,ymax=20)
#       3
#       4 #número de bits y vector de cuantización
#       5 nbits = 3
#
# NameError: name 'my_ceropen' is not defined

# %%
print(tv)
