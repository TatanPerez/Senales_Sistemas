# %% [markdown]
# <a href="https://colab.research.google.com/github/TatanPerez/Senales_Sistemas/blob/main/Talle_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wilmer Sebastian Perez

# %% [markdown]
# *1.1* construir X(s)

# %% [markdown]
# ![1.1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 1.2
# * Determinar los polos y ceros de la transformada de Laplace $\mathsf{L} \{ \epsilon(t) \cdot \sin(\omega_0 t) \}$ mediante el cálculo manual y extendiendo el ejemplo anterior. Qué simetría muestran los polos y los ceros en el plano $s$?

# %% [markdown]
# ![texto alternativo](https://drive.google.com/uc?id=1216ekbyZGlYa7fsEzYcucBOtjD69X4oB)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![texto alternativo](https://drive.google.com/uc?id=122DF_JjLfL1PsMVJZoXmAhB9mqPzsKm7
# )

# %% [markdown]
# ![texto alternativo](https://drive.google.com/uc?id=122F8U4PojhpmB64RUR99NHl_PzLBY1GC)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![texto alternativo](https://drive.google.com/uc?id=1237t3J8neyXpcI8SJfqS_oxhiD2Ylxql)

# %% [markdown]
# ![texto alternativo](https://drive.google.com/uc?id=124BOr97JlQI7KFtcLxsvQseNdw41OhWj)

# %% [markdown]
# 1.5 Consultar los ejercicios de la transformada inversa de laplace

# %%
# %matplotlib inline
import sympy as sym
sym.init_printing() #importar sympy y declarar variables simbólicas

t = sym.symbols('t', real=True)
s = sym.symbols('s', complex=True)
#integral transformada de laplace
X = sym.integrate(sym.DiracDelta(t)*sym.exp(-s*t), (t, -sym.oo, sym.oo))
X
# Out:
# 1

# %%
s0 = sym.symbols('s0', complex=True)
#utilizamos la función de transformada de Laplace de sympy
X, a, cond = sym.laplace_transform(sym.exp(-s0*t), t, s)
X, a, cond
# Out:
# ⎛  1                  ⎞
# ⎜──────, -re(s₀), True⎟
# ⎝s + s₀               ⎠

# %% [markdown]
# *   tener la transformada de laplace inversa de X(s) manualmente

# %% [markdown]
# ![texto alternativo](https://drive.google.com/uc?id=128-BsXa4e74bFlG-GJ2Kb14Sxb2Rhqb_)

# %%
# %matplotlib inline
import sympy as sym
sym.init_printing()

s = sym.symbols('s', complex=True)
t = sym.symbols('t', real=True)

X = (2*s**2 + 14*s + 124)/(s**3 + 8 * s**2 + 46*s + 68)
X
# Out:
#      2
#   2⋅s  + 14⋅s + 124
# ─────────────────────
#  3      2
# s  + 8⋅s  + 46⋅s + 68

# %%
sym.inverse_laplace_transform(X, s, t).simplify() #sin embargo puede ser más costoso computacionalmente
# Out:
#   ⎛   t           ⎞  -3⋅t
# 2⋅⎝2⋅ℯ  - cos(5⋅t)⎠⋅ℯ    ⋅θ(t)

# %% [markdown]
# * Obtener la transformada inversa de la siguiente X(s)

# %% [markdown]
# ![texto alternativo](https://drive.google.com/uc?id=128hCAcIF6T0deCB2obYwbLXu1PCINuvV)

# %%
# %matplotlib inline
import sympy as sym
sym.init_printing()

s = sym.symbols('s', complex=True)
t = sym.symbols('t', real=True)

X = 1/((s+1)*(s+2)**2)
X
# Out:
#        1
# ────────────────
#                2
# (s + 1)⋅(s + 2)

# %%
sym.inverse_laplace_transform(X, s, t).simplify() #sin embargo puede ser más costoso computacionalmente
# Out:
# ⎛      t    ⎞  -2⋅t
# ⎝-t + ℯ  - 1⎠⋅ℯ    ⋅θ(t)

# %% [markdown]
# ![texto alternativo](https://drive.google.com/uc?id=12Dh0jKjmFq43OEP-Zxq1YER7QPcTG8bR)
